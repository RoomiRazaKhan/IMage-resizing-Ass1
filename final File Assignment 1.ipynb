# %%
import numpy as np
import matplotlib.pyplot as plt
im=plt.imread("C:\\Users\\RoomiRaza\\images\\1.jpg")
print(type(im))
print(im.shape)
print()
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
from PIL import Image as im

for i in range(20):
    img=mpimg.imread('C:\\Users\\RoomiRaza\\images\\'+str(i+1)+'.jpg')
    imgplot = plt.imshow(img)
    plt.show()

list1=[]
for i in range(20):
    im1=(im.open('C:\\Users\\RoomiRaza\\images\\'+str(i+1)+'.jpg'))
    im1=im1.resize((500,500),im.ANTIALIAS)
    #print(plt.imshow(im1))
    im1.save('resize'+str(i+1)+'.jpg')
    list1.append(np.array(im1))
print(list1[19])
# Out:
# <class 'numpy.ndarray'>
# (800, 1400, 3)
#
# Populating the interactive namespace from numpy and matplotlib
# [[[116  80  22]
#   [229 186 194]
#   [226 199 245]
#   ...
#   [ 80  61  35]
#   [ 74  62  43]
#   [ 63  55  41]]
#
#  [[170 140  77]
#   [182 141 141]
#   [207 173 212]
#   ...
#   [ 73  56  31]
#   [ 70  58  40]
#   [ 61  51  40]]
#
#  [[217 195 129]
#   [140 100  87]
#   [198 154 181]
#   ...
#   [ 68  56  34]
#   [ 76  68  51]
#   [ 72  62  53]]
#
#  ...
#
#  [[ 51  70   9]
#   [ 98 116  57]
#   [162 174 119]
#   ...
#   [ 72  71  21]
#   [ 47  56  14]
#   [ 45  57   9]]
#
#  [[ 63  85  16]
#   [ 69  87  33]
#   [110 123  75]
#   ...
#   [ 80  78  31]
#   [ 66  71  32]
#   [ 53  64  17]]
#
#  [[ 61  85  11]
#   [ 80  99  49]
#   [ 68  84  35]
#   ...
#   [ 90  90  42]
#   [ 94  96  53]
#   [ 84  87  38]]]
